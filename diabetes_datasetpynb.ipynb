# %%
import numpy as np
import pandas as pd
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5e42d7b0-d108-4a7b-a727-2abe160ddbca" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5e42d7b0-d108-4a7b-a727-2abe160ddbca">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
import pandas as pd
import numpy as np
uploaded=files.upload()

filename=next(iter(uploaded))
data=pd.read_csv(filename)
print("File uploaded:",filename)
print(data.head())
# Out:
#      <input type="file" id="files-c72c601a-4428-4ce8-9122-8e32e5d05d44" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c72c601a-4428-4ce8-9122-8e32e5d05d44">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
print(data[data["heart_disease"] == 1])
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 4        Male  76.0             1              1         current  20.14
# 23     Female  72.0             0              1          former  27.94
# 26       Male  67.0             0              1     not current  27.32
# 42     Female  77.0             1              1           never  32.02
# ...       ...   ...           ...            ...             ...    ...
# 99820  Female  47.0             0              1           never  18.17
# 99826    Male  63.0             0              1         No Info  27.32
# 99848    Male  80.0             1              1          former  28.79
# 99935  Female  65.0             1              1           never  33.55
# 99938    Male  55.0             0              1          former  30.42
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
print(data.tail())
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 99995  Female  80.0             0              0         No Info  27.32
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 99995          6.2                   90         0
# 99996          6.5                  100         0
# 99997          5.7                  155         0
# 99998          4.0                  100         0
# 99999          6.6                   90         0

# %%
print(data.shape)
# Out:
# (100000, 9)

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 9 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   gender               100000 non-null  object
#  1   age                  100000 non-null  float64
#  2   hypertension         100000 non-null  int64
#  3   heart_disease        100000 non-null  int64
#  4   smoking_history      100000 non-null  object
#  5   bmi                  100000 non-null  float64
#  6   HbA1c_level          100000 non-null  float64
#  7   blood_glucose_level  100000 non-null  int64
#  8   diabetes             100000 non-null  int64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 6.9+ MB
# None

# %%
print(data.dtypes)
# Out:
# gender                  object
# age                    float64
# hypertension             int64
# heart_disease            int64
# smoking_history         object
# bmi                    float64
# HbA1c_level            float64
# blood_glucose_level      int64
# diabetes                 int64
# dtype: object

# %%
print(data.duplicated().sum())
# Out:
# 3854

# %%
data = data.drop_duplicates()
print(data.shape)
# Out:
# (96146, 9)

# %%
print(data.describe())
# Out:
#                 age  hypertension  heart_disease           bmi   HbA1c_level  \
# count  96146.000000  96146.000000   96146.000000  96146.000000  96146.000000
# mean      41.794326      0.077601       0.040803     27.321461      5.532609
# std       22.462948      0.267544       0.197833      6.767716      1.073232
# min        0.080000      0.000000       0.000000     10.010000      3.500000
# 25%       24.000000      0.000000       0.000000     23.400000      4.800000
# 50%       43.000000      0.000000       0.000000     27.320000      5.800000
# 75%       59.000000      0.000000       0.000000     29.860000      6.200000
# max       80.000000      1.000000       1.000000     95.690000      9.000000
#
#        blood_glucose_level      diabetes
# count         96146.000000  96146.000000
# mean            138.218231      0.088220
# std              40.909771      0.283616
# min              80.000000      0.000000
# 25%             100.000000      0.000000
# ...

# %%
print(data["age"].max())
# Out:
# 80.0

# %%
print(data["age"].min())
# Out:
# 0.08

# %%
print(data["bmi"].mean())
# Out:
# 27.32146111122668

# %%
print(data["diabetes"].value_counts())
# Out:
# diabetes
# 0    87664
# 1     8482
# Name: count, dtype: int64

# %%
print(data[data["diabetes"] == 1])
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 6      Female  44.0             0              0           never  19.31
# 26       Male  67.0             0              1     not current  27.32
# 38       Male  50.0             1              0         current  27.32
# 40       Male  73.0             0              0          former  25.91
# 53     Female  53.0             0              0          former  27.32
# ...       ...   ...           ...            ...             ...    ...
# 99935  Female  65.0             1              1           never  33.55
# 99938    Male  55.0             0              1          former  30.42
# 99957  Female  61.0             0              0         No Info  34.45
# 99962  Female  58.0             1              0           never  38.31
# 99979  Female  61.0             0              0         current  30.11
#
#        HbA1c_level  blood_glucose_level  diabetes
# 6              6.5                  200         1
# ...

# %%
print(data[data["hypertension"] == 1])
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 4        Male  76.0             1              1         current  20.14
# 28       Male  45.0             1              0           never  26.47
# 38       Male  50.0             1              0         current  27.32
# 42     Female  77.0             1              1           never  32.02
# 54     Female  45.0             1              0           never  23.05
# ...       ...   ...           ...            ...             ...    ...
# 99948  Female  56.0             1              0          former  39.62
# 99953  Female  59.0             1              0            ever  60.52
# 99962  Female  58.0             1              0           never  38.31
# 99963  Female  51.0             1              0         No Info  28.67
# 99984    Male  80.0             1              0         No Info  20.96
#
#        HbA1c_level  blood_glucose_level  diabetes
# 4              4.8                  155         0
# ...

# %%
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0      Female  80.0             0              1           never  25.19
# 1      Female  54.0             0              0         No Info  27.32
# 2        Male  28.0             0              0           never  27.32
# 3      Female  36.0             0              0         current  23.45
# 4        Male  76.0             1              1         current  20.14
# ...       ...   ...           ...            ...             ...    ...
# 99994  Female  36.0             0              0         No Info  24.60
# 99996  Female   2.0             0              0         No Info  17.37
# 99997    Male  66.0             0              0          former  27.83
# 99998  Female  24.0             0              0           never  35.42
# 99999  Female  57.0             0              0         current  22.43
#
#        HbA1c_level  blood_glucose_level  diabetes
# 0              6.6                  140         0
# ...

# %%
print(data.groupby("diabetes")[["age", "bmi", "HbA1c_level", "blood_glucose_level"]].mean())
# Out:
#                 age        bmi  HbA1c_level  blood_glucose_level
# diabetes
# 0         39.943229  26.869003     5.396936           132.818489
# 1         60.925961  31.997755     6.934827           194.026173

# %%
print(data.select_dtypes(include=np.number).corr())
# Out:
#                           age  hypertension  heart_disease       bmi  \
# age                  1.000000      0.257305       0.238451  0.344797
# hypertension         0.257305      1.000000       0.119982  0.148111
# heart_disease        0.238451      0.119982       1.000000  0.061376
# bmi                  0.344797      0.148111       0.061376  1.000000
# HbA1c_level          0.106719      0.081441       0.068140  0.084423
# blood_glucose_level  0.114317      0.084834       0.070832  0.092543
# diabetes             0.264927      0.195710       0.170711  0.214932
#
#                      HbA1c_level  blood_glucose_level  diabetes
# age                     0.106719             0.114317  0.264927
# hypertension            0.081441             0.084834  0.195710
# heart_disease           0.068140             0.070832  0.170711
# bmi                     0.084423             0.092543  0.214932
# HbA1c_level             1.000000             0.171615  0.406408
# ...

# %%
print(data.sort_values("blood_glucose_level", ascending=False))
# Out:
#        gender   age  hypertension  heart_disease smoking_history    bmi  \
# 94     Female  60.0             0              0           never  27.32
# 40121  Female  49.0             0              0          former  25.26
# 99938    Male  55.0             0              1          former  30.42
# 68794    Male  53.0             0              1           never  33.81
# 89833  Female  60.0             0              0     not current  33.52
# ...       ...   ...           ...            ...             ...    ...
# 49134  Female  64.0             0              0     not current  27.32
# 49136  Female  47.0             0              0          former  27.40
# 71221  Female  48.0             0              0         current  25.35
# 49098  Female  22.0             0              0         current  31.92
# 49099  Female  80.0             0              0           never  42.18
#
#        HbA1c_level  blood_glucose_level  diabetes
# 94             7.5                  300         1
# ...
